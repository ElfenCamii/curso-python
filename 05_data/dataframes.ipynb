# %%
import pandas as pd

# %%
df =  pd.DataFrame({'columna1' : [1, 2, 3, 4], 'columna2' : ['a', 'b', 'c', 'd']})

# %%
df
# Out:
#    columna1 columna2
# 0         1        a
# 1         2        b
# 2         3        c
# 3         4        d
