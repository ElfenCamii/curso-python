# %% [markdown]
# # pandas
#
# - Las estructuras principales de pandas son:
#     - las series (vector o columna)
#     - datafrane

# %%
import pandas as pd

# %%
serie = pd.Series([1, 2, 3])

# %%
serie
# Out:
# 0    1
# 1    2
# 2    3
# dtype: int64

# %%
serie.name = 'nombre'

# %%
serie
# Out:
# 0    1
# 1    2
# 2    3
# Name: nombre, dtype: int64
